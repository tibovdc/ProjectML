# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('data/listings.csv')

# data.columns

# %%
data
# Out:
#            id                            listing_url       scrape_id  \
# 0      187870    https://www.airbnb.com/rooms/187870  20210716195504
# 1      203806    https://www.airbnb.com/rooms/203806  20210716195504
# 2      204245    https://www.airbnb.com/rooms/204245  20210716195504
# 3      216715    https://www.airbnb.com/rooms/216715  20210716195504
# 4      252269    https://www.airbnb.com/rooms/252269  20210716195504
# ..        ...                                    ...             ...
# 918  51022259  https://www.airbnb.com/rooms/51022259  20210716195504
# 919  51036302  https://www.airbnb.com/rooms/51036302  20210716195504
# 920  51053223  https://www.airbnb.com/rooms/51053223  20210716195504
# 921  51056846  https://www.airbnb.com/rooms/51056846  20210716195504
# 922  51061671  https://www.airbnb.com/rooms/51061671  20210716195504
#
#     last_scraped                                               name  \
# 0     2021-07-16  Luxury studio 'Spiegelhof' in the centre of Ghent
# 1     2021-07-16                Flat close to Sint-Pieters Station!
# 2     2021-07-16                    Modern studio's in Ghent centre
# 3     2021-07-16                                     converted loft
# 4     2021-07-16  Large & bright town House - Center Ghent - max 8p
# ..           ...                                                ...
# 918   2021-07-16           Full apartment near Sint Pieters Station
# 919   2021-07-16                                   Guesthouse Flora
# 920   2021-07-16  Large modern house 10min from downtown Ghent/Gent
# 921   2021-07-16  Comfort, quiet en green in ancient part of center
# 922   2021-07-16      Comfortable spacious bedroom near shops & uni
#
#                                            description  \
# 0    The top floor of our house in the center of Gh...
# 1    This well-located and comfortable one-bedroom ...
# 2    <b>The space</b><br />We offer luxury studio's...
# 3    Please read full desription for how to get the...
# 4    bright, spacious, authentic & beautifully rest...
# ..                                                 ...
# 918  This is a 2 bedroom apartment.  Guests will en...
# 919  Geniet van de moderne en ouderwetse charme van...
# 920  Just 10 minutes from historic downtown Ghent. ...
# 921                                                NaN
# 922  Gent is a beautiful city. Come and explore thi...
#
#                                  neighborhood_overview  \
# 0    We live in a quiet and pleasant neighborhood w...
# 1    The house is located in a dead-end street - so...
# 2                                                  NaN
# 3    It's close to all that you will want or need v...
# 4    our neighbourhood is quiet, but nicely vibrati...
# ..                                                 ...
# 918  Apartment is located in neighborhood of Sint P...
# 919  De Flora is het meest noordelijke gedeelte van...
# 920                                                NaN
# 921                                                NaN
# 922                                                NaN
#
#                                            picture_url  \
# 0    https://a0.muscache.com/pictures/26c46224-795c...
# 1    https://a0.muscache.com/pictures/fe477b7f-93ac...
# 2    https://a0.muscache.com/pictures/1766072/02965...
# 3    https://a0.muscache.com/pictures/1927009/20760...
# 4    https://a0.muscache.com/pictures/69675b54-3e78...
# ..                                                 ...
# 918   the main station in Ghent. The street is very...
# 919  https://a0.muscache.com/pictures/186f59af-f089...
# 920  https://a0.muscache.com/pictures/7de8d4c4-0155...
# 921  https://a0.muscache.com/pictures/a7faff71-0c08...
# 922  https://a0.muscache.com/pictures/miso/Hosting-...
#
#                                                host_id  \
# 0                                               904277
# 1                                               999847
# 2                                              1003009
# 3                                               911466
# 4                                              1195314
# ..                                                 ...
# 918  https://a0.muscache.com/pictures/47c0402d-8d28...
# 919                                          171955140
# 920                                            2650664
# 921                                           45920980
# 922                                          412643939
#
#                                         host_url  ... review_scores_location  \
# 0       https://www.airbnb.com/users/show/904277  ...                   4.58
# 1       https://www.airbnb.com/users/show/999847  ...                   4.49
# 2      https://www.airbnb.com/users/show/1003009  ...                   4.97
# 3       https://www.airbnb.com/users/show/911466  ...                   4.89
# 4      https://www.airbnb.com/users/show/1195314  ...                   4.98
# ..                                           ...  ...                    ...
# 918                                     97573561  ...                    NaN
# 919  https://www.airbnb.com/users/show/171955140  ...                    NaN
# 920    https://www.airbnb.com/users/show/2650664  ...                    NaN
# 921   https://www.airbnb.com/users/show/45920980  ...                    NaN
# 922  https://www.airbnb.com/users/show/412643939  ...                    NaN
#
#     review_scores_value license instant_bookable  \
# 0                  4.85     NaN                t
# 1                  4.54     NaN                f
# 2                  4.63     NaN                f
# 3                  4.76     NaN                t
# 4                  4.72     NaN                f
# ..                  ...     ...              ...
# 918                 NaN     NaN              NaN
# 919                 NaN     NaN                f
# 920                 NaN     NaN                t
# 921                 NaN     NaN                t
# 922                 NaN     NaN                t
#
#     calculated_host_listings_count  \
# 0                                1
# 1                                2
# 2                                2
# 3                                1
# 4                                1
# ..                             ...
# 918                              f
# 919                              1
# 920                              1
# 921                              2
# 922                              2
#
#     calculated_host_listings_count_entire_homes  \
# 0                                             0
# 1                                             2
# 2                                             2
# 3                                             1
# 4                                             1
# ..                                          ...
# 918                                           2
# 919                                           1
# 920                                           1
# 921                                           0
# 922                                           0
#
#     calculated_host_listings_count_private_rooms  \
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ..                                           ...
# 918                                            1
# 919                                            0
# 920                                            0
# 921                                            2
# 922                                            2
#
#     calculated_host_listings_count_shared_rooms reviews_per_month Unnamed: 74
# 0                                             0              3.61         NaN
# 1                                             0              2.84         NaN
# 2                                             0              0.29         NaN
# 3                                             0              4.31         NaN
# 4                                             0              2.23         NaN
# ..                                          ...               ...         ...
# 918                                           1              0.00         NaN
# 919                                           0               NaN         NaN
# 920                                           0               NaN         NaN
# 921                                           0               NaN         NaN
# 922                                           0               NaN         NaN
#
# [923 rows x 75 columns]

# %%
data_cleaned = data
# Some columns are shifted by an excessive comma. We shifted these columns by looking for errors in 'host_since'.
shifted = data_cleaned[data_cleaned['host_since'].str.match("20[0-2][0-9]-[0-1][0-9]-[0-3][0-9]")==False]
data_cleaned = data_cleaned[data_cleaned['host_since'].str.match("20[0-2][0-9]-[0-1][0-9]-[0-3][0-9]")==True]
shifted = shifted.shift(periods=-1, axis=1)
shifted['host_since']
data_cleaned.append(shifted)
# Out:
#                                         id  \
# 0                                   187870
# 1                                   203806
# 2                                   204245
# 3                                   216715
# 4                                   252269
# ..                                     ...
# 515  https://www.airbnb.com/rooms/35279903
# ..                                                 ...        ...
# 515  https://a0.muscache.com/pictures/60412037-544b...  242219560
# 516  https://a0.muscache.com/pictures/aeecf01e-7dfa...  242219560
# 537  https://a0.muscache.com/pictures/e006cafc-6a90...  274438998
# 841  https://a0.muscache.com/pictures/miso/Hosting-...   31377738
# 918  https://a0.muscache.com/pictures/47c0402d-8d28...   97573561
#
#                                         host_url  ... review_scores_location  \
# 0       https://www.airbnb.com/users/show/904277  ...                   4.58
# 1       https://www.airbnb.com/users/show/999847  ...                   4.49
# 2      https://www.airbnb.com/users/show/1003009  ...                   4.97
# 3       https://www.airbnb.com/users/show/911466  ...                   4.89
# 4      https://www.airbnb.com/users/show/1195314  ...                   4.98
# ..                                           ...  ...                    ...
# 515  https://www.airbnb.com/users/show/242219560  ...                   4.60
# 516  https://www.airbnb.com/users/show/242219560  ...                   4.80
# 537  https://www.airbnb.com/users/show/274438998  ...                   4.77
# 841   https://www.airbnb.com/users/show/31377738  ...                   5.00
# 918   https://www.airbnb.com/users/show/97573561  ...                    NaN
#
#     review_scores_value license instant_bookable  \
# 0                  4.85     NaN                t
# 1                  4.54     NaN                f
# 2                  4.63     NaN                f
# 3                  4.76     NaN                t
# 4                  4.72     NaN                f
# ..                  ...     ...              ...
# 515                4.80     NaN                t
# 516                4.60     NaN                t
# 537                4.62     NaN                f
# 841                5.00     NaN                t
# 918                 NaN     NaN                f
#
#     calculated_host_listings_count  \
# 0                                1
# 1                                2
# 2                                2
# 3                                1
# 4                                1
# ..                             ...
# 515                              2
# 516                              2
# 537                              1
# 841                              1
# 918                              2
#
#     calculated_host_listings_count_entire_homes  \
# 0                                             0
# 1                                             2
# 2                                             2
# 3                                             1
# 4                                             1
# ..                                          ...
# 515                                           2
# 516                                           2
# 537                                           0
# 841                                           0
# 918                                           1
#
#     calculated_host_listings_count_private_rooms  \
# 0                                              1
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
# ..                                           ...
# 515                                            0
# 516                                            0
# 537                                            0
# 841                                            1
# 918                                            1
#
#     calculated_host_listings_count_shared_rooms reviews_per_month Unnamed: 74
# 0                                           0.0              3.61         NaN
# 1                                           0.0              2.84         NaN
# 2                                           0.0              0.29         NaN
# 3                                           0.0              4.31         NaN
# 4                                           0.0              2.23         NaN
# ..                                          ...               ...         ...
# 515                                         0.0              0.51         NaN
# 516                                         0.0              0.25         NaN
# 537                                         1.0              0.67         NaN
# 841                                         0.0              0.48         NaN
# 918                                         0.0               NaN         NaN
#
# [923 rows x 75 columns]

# %%
data[data['host_since'].str.match("20[0-2][0-9]-[0-1][0-9]-[0-3][0-9]")==False]
# Out:
#            id                            listing_url       scrape_id  \
# 296  20842771  https://www.airbnb.com/rooms/20842771  20210716195504
# 515  35279903  https://www.airbnb.com/rooms/35279903  20210716195504
# 516  35297611  https://www.airbnb.com/rooms/35297611  20210716195504
# 537  36503556  https://www.airbnb.com/rooms/36503556  20210716195504
# 841  49136989  https://www.airbnb.com/rooms/49136989  20210716195504
# 918  51022259  https://www.airbnb.com/rooms/51022259  20210716195504
#
#     last_scraped                                               name  \
# 296   2021-07-16                      Gezinswoning in rustige buurt
# 515   2021-07-16     Box in a Box (Beam)  -  A rural gift, open it!
# 516   2021-07-16       Box in a Box (Cube) - a rural gift, open it!
# 537   2021-07-16  Visiting Gent! save money! many options to enjoy!
# 841   2021-07-16                            Boatie's * Bed bad boot
# 918   2021-07-16           Full apartment near Sint Pieters Station
#
#                                            description  \
# 296  Ruime woning met alle voorzieningen. Uitzicht ...
# 515  www.boxinabox.be                              ...
# 516  www.boxinabox.be                              ...
# 537  Small place with a big heart! <br />The goal o...
# 841  Aye!<br />Langs de oever van de Schelde stelle...
# 918  This is a 2 bedroom apartment.  Guests will en...
#
#                                  neighborhood_overview  \
# 296      Rustige buurt. Zalige nachtrust gegarandeerd
# 515  Village (Drongen) 2km <br />City by bike (Ghen...
# 516  Village (Drongen) 2km <br />City by bike (Ghen...
# 537  )<br /><br /><b>The space</b><br />The studio ...
# 841  De woonboot ligt op de groene Scheldearm tusse...
# 918  Apartment is located in neighborhood of Sint P...
#
#                                            picture_url  \
# 296                                                 -)
# 515                                                1km
# 516                                                1km
# 537  They are really kind and i've not heard noise ...
# 841                          alsook de zondagse markt!
# 918   the main station in Ghent. The street is very...
#
#                                                host_id   host_url  ...  \
# 296  https://a0.muscache.com/pictures/ada4816b-92f5...   35397446  ...
# 515  https://a0.muscache.com/pictures/60412037-544b...  242219560  ...
# 516  https://a0.muscache.com/pictures/aeecf01e-7dfa...  242219560  ...
# 537  https://a0.muscache.com/pictures/e006cafc-6a90...  274438998  ...
# 841  https://a0.muscache.com/pictures/miso/Hosting-...   31377738  ...
# 918  https://a0.muscache.com/pictures/47c0402d-8d28...   97573561  ...
#
#     review_scores_location review_scores_value license instant_bookable  \
# 296                   5.00                4.86    5.00              NaN
# 515                   5.00                4.60    4.80              NaN
# 516                   5.00                4.80    4.60              NaN
# 537                   4.69                4.77    4.62              NaN
# 841                   5.00                5.00    5.00              NaN
# 918                    NaN                 NaN     NaN              NaN
#
#     calculated_host_listings_count  \
# 296                              f
# 515                              t
# 516                              t
# 537                              f
# 841                              t
# 918                              f
#
#     calculated_host_listings_count_entire_homes  \
# 296                                           1
# 515                                           2
# 516                                           2
# 537                                           1
# 841                                           1
# 918                                           2
#
#     calculated_host_listings_count_private_rooms  \
# 296                                            1
# 515                                            2
# 516                                            2
# 537                                            0
# 841                                            0
# 918                                            1
#
#     calculated_host_listings_count_shared_rooms reviews_per_month Unnamed: 74
# 296                                           0               0.0        0.20
# 515                                           0               0.0        0.51
# 516                                           0               0.0        0.25
# 537                                           0               1.0        0.67
# 841                                           1               0.0        0.48
# 918                                           1               0.0         NaN
#
# [6 rows x 75 columns]
